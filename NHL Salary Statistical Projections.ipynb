# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  #for plotting purpose
import statsmodels.api as sm

# %%
players = pd.read_csv('C:/Users/night/players.csv')
player_data = players.drop(['Player', 'Season', 'Team', 'Position', 'Cap Group'], axis = 1)
player_group = players.drop(['Player', 'Season', 'Team', 'Position', 'Pct Cap'], axis = 1)

# %%
x = player_data.drop('Pct Cap', axis = 1)
y = player_data['Pct Cap']
from sklearn.model_selection import train_test_split

# We specify random seed so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(player_data, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
# Note the difference in argument order
model = sm.OLS(y, x).fit()
predictions = model.predict(x) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                Pct Cap   R-squared (uncentered):                   0.905
# Model:                            OLS   Adj. R-squared (uncentered):              0.903
# Method:                 Least Squares   F-statistic:                              366.3
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):                        0.00
# Time:                        01:30:52   Log-Likelihood:                          2884.7
# No. Observations:                1142   AIC:                                     -5711.
# Df Residuals:                    1113   BIC:                                     -5565.
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# Checking for the VIF values of the variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Creating a dataframe that will contain the names of all the feature variables and their VIFs
vif = pd.DataFrame()
vif['Features'] = df_train.columns
vif['VIF'] = [variance_inflation_factor(df_train.values, i) for i in range(df_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#          Features      VIF
# 15  Fenwick Shots  1077.28
# 8             DZF   587.63
# 7             NZF   582.23
# 16    Corsi Shots   559.04
# 14  Shots on Goal   428.97
# 6             OZF   405.26
# 3             NZS   392.11
# 4             DZS   314.50
# 2             OZS   259.85
# 5             OTF   143.23
# 0              GP   131.24
# 17            ixG    78.48
# 9           Ice_F    68.41
# 10          Ice_A    56.13
# 27            FOW    48.17
# 28            FOL    46.21
# 1            TOI%    45.39
# 25   Majors Taken    37.14
# 26   Majors Drawn    35.84
# 11              G    20.65
# 22   Hits Against    13.35
# 20      Takeaways    12.42
# 12             A1    12.09
# 19      Giveaways    11.47
# 13             A2    11.15
# 18         Blocks    10.50
# 29        Pct Cap    10.14
# 24   Minors Drawn     9.55
# 23   Minors Taken     8.45
# 21           Hits     6.14

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# predicting the accuracy score
score= r2_score(df_test,predictions)
print('r2 score is: ',score)
print('mean_sqrd_error is: ',mean_squared_error(df_test,predictions))
print('root_mean_squared error of is: ',np.sqrt(mean_squared_error(df_test,predictions)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-cb0db1136148> in <module>
#       4
#       5 # predicting the accuracy score
# ----> 6 score= r2_score(df_test,predictions)
#       7 print('r2 score is: ',score)
#       8 print('mean_sqrd_error is: ',mean_squared_error(df_test,predictions))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     586     -3.0
#     587     """
# --> 588     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# ...

# %%
x = player_group.drop('Cap Group', axis = 1)
y = player_group['Cap Group']

from sklearn.model_selection import train_test_split

# Extract the labels
labels = np.array(player_group.pop('Cap Group'))

# 30% examples in test data
train, test, train_labels, test_labels = train_test_split(player_group, labels, 
                                                          stratify = labels,
                                                          test_size = 0.3, 
                                                          random_state = 12345)

# %%
# Train tree
tree.fit(train, train_labels)
print(f'Decision tree has {tree.tree_.node_count} nodes with maximum depth {tree.tree_.max_depth}.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f7dd0c62cc93> in <module>
#       1 # Train tree
# ----> 2 tree.fit(train, train_labels)
#       3 print(f'Decision tree has {tree.tree_.node_count} nodes with maximum depth {tree.tree_.max_depth}.')
#
# NameError: name 'tree' is not defined

# %%
# test classification dataset
from sklearn.datasets import make_classification

# summarize the dataset
print(x.shape, y.shape)
# Out:
# (1142, 29) (1142,)

# %%
# evaluate random forest algorithm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# define the model
model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
# evaluate the model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, x, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.529 (0.040)

# %%
# Actual class predictions
model.fit(train, train_labels)
rf_predictions = model.predict(test)
# Probabilities for each class
rf_probs = model.predict_proba(test)[:, 1]

# %%
from sklearn.metrics import roc_auc_score

# Calculate roc auc
roc_value = roc_auc_score(test_labels, rf_probs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-461b92ebdccd> in <module>
#       2
#       3 # Calculate roc auc
# ----> 4 roc_value = roc_auc_score(test_labels, rf_probs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     382                              "instead".format(max_fpr))
#     383         if multi_class == 'raise':
# --> 384             raise ValueError("multi_class must be in ('ovo', 'ovr')")
# ...
